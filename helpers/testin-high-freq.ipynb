# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rate = 44100
seconds = 6
t = np.linspace(0, seconds, rate * seconds)
frq = np.linspace(70, 1200, rate * seconds)
s = np.sin(2 * np.pi * frq * t)

# %%
plt.plot(t, s)

# %%
nperseg  = 10000
noverlap = 9000
step = nperseg - noverlap

# %%
plt.plot(chunk)

# %%
frame_height = 1080
t = np.linspace(0, nperseg / rate, nperseg)
f = np.geomspace(30, nperseg // 2, frame_height) # second arg: nperseg//2 (Nyquist limit)    
T, F = np.meshgrid(t, f)
E = np.array(np.exp(-2j * np.pi * F * T), dtype=np.complex64) # complex64: Complex number, represented by two 32-bit floats (real and imaginary components)

# %%
# np.logspace(2, 3, 3)
np.geomspace(100, 1200, 10)
# Out:
# array([ 100.        ,  131.79806292,  173.7072939 ,  228.94284851,
#         301.74223953,  397.69042672,  524.14827884,  690.81727835,
#         910.48379119, 1200.        ])

# %%
plt.figure(figsize=(20, 10))


for k in range(2000, 100000, 10000):
#     k = 40000
    chunk = s[k:k + nperseg]
    corr = np.dot(chunk, E.T)
    magnitude = np.abs(corr)
    spectrogram = magnitude.T
    plt.plot(spectrogram)

    plt.semilogx()
plt.xlim([70, 2000])
plt.savefig('a1b2b3b.png', transparent=True)
